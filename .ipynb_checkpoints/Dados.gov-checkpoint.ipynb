# %% [markdown]
# # Data Wrangling Project: WeRateDogs Twitter Data

# %% [markdown]
# ## Introduction

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams
# %matplotlib inline
from PIL import Image
from io import BytesIO
import numpy as np
import requests
import tweepy
import json
from PIL import Image
from io import BytesIO

pd.set_option('float_format', '{:f}'.format)

# %% [markdown]
# ### Gathering

# %%
archive = pd.read_csv('twitter_archive_enhanced.csv')
archive.shape
# Out:
# (2356, 17)

# %%
url = "https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv"
response = requests.get(url)
print(response.status_code)

with open("image_predictions.tsv", mode='wb') as file:
    file.write(response.content)

predict = pd.read_csv('image_predictions.tsv', sep='\t')
predict.shape
# Out:
# 200
# (2075, 12)

# %% [raw]
# consumer_key = " "
# consumer_secret = " "
# auth = tweepy.AppAuthHandler(consumer_key, consumer_secret)
# api = tweepy.API(auth, wait_on_rate_limit=True)
#
# tweet_ids = predict.tweet_id.values
# len(tweet_ids)

# %% [raw]
# %%time
#
# # Query Twitter's API for JSON data
# count = 0
# fails_dict = {}
#
# with open('tweet_json.txt', 'w') as outfile:
#   for tweet_id in tweet_ids:
#         count += 1
#         print(str(count) + ": " + str(tweet_id))
#         try:
#             tweet = api.get_status(tweet_id, tweet_mode='extended')
#             json.dump(tweet._json, outfile)
#             print("Success")
#             outfile.write('\n')
#         except Exception as e:
#             print("Fail")
#             fails_dict[tweet_id] = e
#             pass
#
#
# print(fails_dict)

# %%
json = pd.read_json('tweet_json.txt', lines=True)

# %%
json["tweet_id"]=json["id"]

# %%
json
# Out:
#                     created_at                  id              id_str  \
# 0    2015-11-15 22:32:08+00:00  666020888022790149  666020888022790144
# 1    2015-11-15 23:05:30+00:00  666029285002620928  666029285002620928
# 2    2015-11-15 23:21:54+00:00  666033412701032449  666033412701032448
# 3    2015-11-16 00:04:52+00:00  666044226329800704  666044226329800704
# 4    2015-11-16 00:24:50+00:00  666049248165822465  666049248165822464
# ...                        ...                 ...                 ...
# 2051 2017-07-29 16:00:24+00:00  891327558926688256  891327558926688256
# 2052 2017-07-30 15:58:51+00:00  891689557279858688  891689557279858688
# 2053 2017-07-31 00:18:03+00:00  891815181378084864  891815181378084864
# 2054 2017-08-01 00:17:27+00:00  892177421306343426  892177421306343424
# 2055 2017-08-01 16:23:56+00:00  892420643555336193  892420643555336192
#
#                                               full_text  truncated  \
# 0     Here we have a Japanese Irish Setter. Lost eye...      False
# 1     This is a western brown Mitsubishi terrier. Up...      False
# 2     Here is a very happy pup. Big fan of well-main...      False
# 3     This is a purebred Piers Morgan. Loves to Netf...      False
# 4     Here we have a 1949 1st generation vulpix. Enj...      False
# ...                                                 ...        ...
# 2051  This is Franklin. He would like you to stop ca...      False
# 2052  This is Darla. She commenced a snooze mid meal...      False
# 2053  This is Archie. He is a rare Norwegian Pouncin...      False
# 2054  This is Tilly. She's just checking pup on you....      False
# 2055  This is Phineas. He's a mystical boy. Only eve...      False
#
#      display_text_range                                           entities  \
# 0              [0, 131]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1              [0, 139]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2              [0, 130]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3              [0, 137]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4              [0, 120]  {'hashtags': [], 'symbols': [], 'user_mentions...
# ...                 ...                                                ...
# 2051           [0, 138]  {'hashtags': [{'text': 'BarkWeek', 'indices': ...
# 2052            [0, 79]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2053           [0, 121]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2054           [0, 138]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2055            [0, 85]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                       extended_entities  \
# 0     {'media': [{'id': 666020881337073664, 'id_str'...
# 1     {'media': [{'id': 666029276303482880, 'id_str'...
# 2     {'media': [{'id': 666033409081393153, 'id_str'...
# 3     {'media': [{'id': 666044217047650304, 'id_str'...
# 4     {'media': [{'id': 666049244999131136, 'id_str'...
# ...                                                 ...
# 2051  {'media': [{'id': 891327551943041024, 'id_str'...
# 2052  {'media': [{'id': 891689552724799489, 'id_str'...
# 2053  {'media': [{'id': 891815175371796480, 'id_str'...
# 2054  {'media': [{'id': 892177413194625024, 'id_str'...
# 2055  {'media': [{'id': 892420639486877696, 'id_str'...
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/iphone" r...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/iphone" r...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 2051  <a href="http://twitter.com/download/iphone" r...
# 2052  <a href="http://twitter.com/download/iphone" r...
# 2053  <a href="http://twitter.com/download/iphone" r...
# 2054  <a href="http://twitter.com/download/iphone" r...
# 2055  <a href="http://twitter.com/download/iphone" r...
#
#       in_reply_to_status_id  ...  is_quote_status  retweet_count  \
# 0                       NaN  ...            False            416
# 1                       NaN  ...            False             39
# 2                       NaN  ...            False             35
# 3                       NaN  ...            False            113
# 4                       NaN  ...            False             36
# ...                     ...  ...              ...            ...
# 2051                    NaN  ...            False           7620
# 2052                    NaN  ...            False           7103
# 2053                    NaN  ...            False           3427
# 2054                    NaN  ...            False           5193
# 2055                    NaN  ...            False           6893
#
#       favorite_count favorited retweeted  possibly_sensitive  \
# 0               2234     False     False               False
# 1                111     False     False               False
# 2                 98     False     False               False
# 3                244     False     False               False
# 4                 86     False     False               False
# ...              ...       ...       ...                 ...
# 2051           34385     False     False               False
# 2052           35974     False     False               False
# 2053           21435     False     False               False
# 2054           28505     False     False               False
# 2055           32964     False     False               False
#
#       possibly_sensitive_appealable lang  retweeted_status            tweet_id
# 0                             False   en               NaN  666020888022790149
# 1                             False   en               NaN  666029285002620928
# 2                             False   en               NaN  666033412701032449
# 3                             False   en               NaN  666044226329800704
# 4                             False   en               NaN  666049248165822465
# ...                             ...  ...               ...                 ...
# 2051                          False   en               NaN  891327558926688256
# 2052                          False   en               NaN  891689557279858688
# 2053                          False   en               NaN  891815181378084864
# 2054                          False   en               NaN  892177421306343426
# 2055                          False   en               NaN  892420643555336193
#
# [2056 rows x 29 columns]

# %%
#Selecting columns 
twitter_api = json[['tweet_id','retweet_count', 'favorite_count']]

# %%
# Merging for Assesing

m1 = pd.merge(twitter_api,archive, on="tweet_id",how='left')
m2 = pd.merge(m1,predict, on="tweet_id",how='left')
df_final = m2

# %% [markdown]
# ## Assesing

# %%
pd.set_option("max_colwidth", 10)
pd.set_option('display.max_columns', 30)
df_final.head()
# Out:
#     tweet_id  retweet_count  favorite_count  in_reply_to_status_id  \
# 0  666020...        416           2234             NaN
# 1  666029...         39            111             NaN
# 2  666033...         35             98             NaN
# 3  666044...        113            244             NaN
# 4  666049...         36             86             NaN
#
#    in_reply_to_user_id  timestamp     source       text  retweeted_status_id  \
# 0        NaN            2015-1...  <a hre...  Here w...        NaN
# 1        NaN            2015-1...  <a hre...  This i...        NaN
# 2        NaN            2015-1...  <a hre...  Here i...        NaN
# 3        NaN            2015-1...  <a hre...  This i...        NaN
# 4        NaN            2015-1...  <a hre...  Here w...        NaN
#
#    retweeted_status_user_id retweeted_status_timestamp expanded_urls  \
# 0        NaN                       NaN                  https:...
# 1        NaN                       NaN                  https:...
# 2        NaN                       NaN                  https:...
# 3        NaN                       NaN                  https:...
# 4        NaN                       NaN                  https:...
#
#    rating_numerator  rating_denominator  name doggo floofer pupper puppo  \
# 0          8                10           None  None    None   None  None
# 1          7                10              a  None    None   None  None
# 2          9                10              a  None    None   None  None
# 3          6                10              a  None    None   None  None
# 4          5                10           None  None    None   None  None
#
#      jpg_url  img_num         p1  p1_conf  p1_dog         p2  p2_conf  p2_dog  \
# 0  https:...        1  Welsh_... 0.465074    True     collie 0.156665    True
# 1  https:...        1    redbone 0.506826    True  miniat... 0.074192    True
# 2  https:...        1  German... 0.596461    True   malinois 0.138584    True
# 3  https:...        1  Rhodes... 0.408143    True    redbone 0.360687    True
# 4  https:...        1  miniat... 0.560311    True  Rottwe... 0.243682    True
#
#           p3  p3_conf  p3_dog
# 0  Shetla... 0.061428    True
# 1  Rhodes... 0.072010    True
# 2  bloodh... 0.116197    True
# 3  miniat... 0.222752    True
# 4   Doberman 0.154629    True

# %%
df_final.tail()
# Out:
#        tweet_id  retweet_count  favorite_count  in_reply_to_status_id  \
# 2051  891327...       7620          34385             NaN
# 2052  891689...       7103          35974             NaN
# 2053  891815...       3427          21435             NaN
# 2054  892177...       5193          28505             NaN
# 2055  892420...       6893          32964             NaN
#
#       in_reply_to_user_id  timestamp     source       text  \
# 2051        NaN            2017-0...  <a hre...  This i...
# 2052        NaN            2017-0...  <a hre...  This i...
# 2053        NaN            2017-0...  <a hre...  This i...
# 2054        NaN            2017-0...  <a hre...  This i...
# 2055        NaN            2017-0...  <a hre...  This i...
#
#       retweeted_status_id  retweeted_status_user_id  \
# 2051        NaN                  NaN
# 2052        NaN                  NaN
# 2053        NaN                  NaN
# 2054        NaN                  NaN
# 2055        NaN                  NaN
#
#      retweeted_status_timestamp expanded_urls  rating_numerator  \
# 2051        NaN                  https:...            12
# 2052        NaN                  https:...            13
# 2053        NaN                  https:...            12
# 2054        NaN                  https:...            13
# 2055        NaN                  https:...            13
#
#       rating_denominator      name doggo floofer pupper puppo    jpg_url  \
# 2051         10           Franklin  None    None   None  None  https:...
# 2052         10              Darla  None    None   None  None  https:...
# 2053         10             Archie  None    None   None  None  https:...
# 2054         10              Tilly  None    None   None  None  https:...
# 2055         10            Phineas  None    None   None  None  https:...
#
#       img_num         p1  p1_conf  p1_dog         p2  p2_conf  p2_dog  \
# 2051        2     basset 0.555712    True  Englis... 0.225770    True
# 2052        1  paper_... 0.170278   False  Labrad... 0.168086    True
# 2053        1  Chihuahua 0.716012    True   malamute 0.078253    True
# 2054        1  Chihuahua 0.323581    True   Pekinese 0.090647    True
# 2055        1     orange 0.097049   False      bagel 0.085851   False
#
#              p3  p3_conf  p3_dog
# 2051  German... 0.175219    True
# 2052    spatula 0.040836   False
# 2053     kelpie 0.031379    True
# 2054   papillon 0.068957    True
# 2055     banana 0.076110   False

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2056 entries, 0 to 2055
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2056 non-null   int64
#  1   retweet_count               2056 non-null   int64
#  2   favorite_count              2056 non-null   int64
#  3   in_reply_to_status_id       23 non-null     float64
#  4   in_reply_to_user_id         23 non-null     float64
#  5   timestamp                   2056 non-null   object
#  6   source                      2056 non-null   object
#  7   text                        2056 non-null   object
#  8   retweeted_status_id         70 non-null     float64
#  9   retweeted_status_user_id    70 non-null     float64
#  10  retweeted_status_timestamp  70 non-null     object
#  11  expanded_urls               2056 non-null   object
#  12  rating_numerator            2056 non-null   int64
#  13  rating_denominator          2056 non-null   int64
#  14  name                        2056 non-null   object
#  15  doggo                       2056 non-null   object
#  16  floofer                     2056 non-null   object
#  17  pupper                      2056 non-null   object
#  18  puppo                       2056 non-null   object
#  19  jpg_url                     2056 non-null   object
#  20  img_num                     2056 non-null   int64
#  21  p1                          2056 non-null   object
#  22  p1_conf                     2056 non-null   float64
#  23  p1_dog                      2056 non-null   bool
#  24  p2                          2056 non-null   object
#  25  p2_conf                     2056 non-null   float64
#  26  p2_dog                      2056 non-null   bool
#  27  p3                          2056 non-null   object
#  28  p3_conf                     2056 non-null   float64
#  29  p3_dog                      2056 non-null   bool
# dtypes: bool(3), float64(7), int64(6), object(14)
# memory usage: 455.8+ KB

# %%
df_final.describe()
# Out:
#         tweet_id  retweet_count  favorite_count  in_reply_to_status_id  \
# count 2056.00... 2056.00...     2056.00...       23.000000
# mean  7377003... 2324.19...     7265.58...      6978111...
# std   6751436... 4062.06...     10992.5...      4359383...
# min   6660208...  11.000000       0.000000      6671521...
# 25%   6762329... 494.750000     1385.25...      6732410...
# 50%   7110025... 1094.00...     3183.00...      6757073...
# 75%   7928012... 2673.25...     9028.75...      7031489...
# max   8924206... 69521.0...     142035....      8558181...
#
#        in_reply_to_user_id  retweeted_status_id  retweeted_status_user_id  \
# count  23.000000            70.000000            70.000000
# mean  4196983...           7592547...           1124945...
# std     0.000000           5695445...           9411968...
# min   4196983...           6675093...           783214....
# 25%   4196983...           7086319...           4196983...
# 50%   4196983...           7755992...           4196983...
# 75%   4196983...           7947981...           4196983...
# max   4196983...           8650134...           7874617...
#
#        rating_numerator  rating_denominator    img_num    p1_conf    p2_conf  \
# count 2056.00...        2056.00...          2056.00... 2056.00... 2056.00...
# mean   12.265078         10.516051            1.204280   0.594386   0.134767
# std    40.867720          7.210005            0.563359   0.271242   0.100744
# min     0.000000          2.000000            1.000000   0.044333   0.000000
# 25%    10.000000         10.000000            1.000000   0.363272   0.053894
# 50%    11.000000         10.000000            1.000000   0.587797   0.118635
# 75%    12.000000         10.000000            1.000000   0.844247   0.195667
# max   1776.00...        170.000000            4.000000   1.000000   0.488014
#
#          p3_conf
# count 2056.00...
# mean    0.060402
# std     0.051003
# min     0.000000
# 25%     0.016234
# 50%     0.049479
# 75%     0.092157
# max     0.273419

# %%
df_final.describe(include=[object])
# Out:
#         timestamp     source       text retweeted_status_timestamp  \
# count        2056       2056       2056         70
# unique       2056          3       2056         70
# top     2015-1...  <a hre...  Here w...  2015-1...
# freq            1       2016          1          1
#
#        expanded_urls  name doggo floofer pupper puppo    jpg_url         p1  \
# count        2056     2056  2056    2056   2056  2056       2056       2056
# unique       2056      934     2       2      2     2       1997        377
# top     https:...     None  None    None   None  None  https:...  golden...
# freq            1      570  1978    2048   1836  2032          2        150
#
#                p2         p3
# count        2056       2056
# unique        402        407
# top     Labrad...  Labrad...
# freq          104         79

# %%
#Cheking for nulls
df_final.isnull().values.sum()
# Out:
# 10024

# %%
df_final.isnull().sum()
# Out:
# tweet_id                         0
# retweet_count                    0
# favorite_count                   0
# in_reply_to_status_id         2033
# in_reply_to_user_id           2033
# timestamp                        0
# source                           0
# text                             0
# retweeted_status_id           1986
# retweeted_status_user_id      1986
# retweeted_status_timestamp    1986
# expanded_urls                    0
# rating_numerator                 0
# rating_denominator               0
# name                             0
# doggo                            0
# floofer                          0
# pupper                           0
# puppo                            0
# jpg_url                          0
# img_num                          0
# p1                               0
# p1_conf                          0
# p1_dog                           0
# p2                               0
# p2_conf                          0
# p2_dog                           0
# p3                               0
# p3_conf                          0
# p3_dog                           0
# dtype: int64

# %%
#Checking numerator rating
df_final.rating_numerator.value_counts().sort_index(ascending=True)
# Out:
# 0         2
# 1         5
# 2         9
# 3        19
# 4        16
# 5        34
# 6        32
# 7        52
# 8        95
# 9       151
# 10      425
# 11      413
# 12      471
# 13      275
# 14       37
# 15        1
# 24        1
# 26        1
# 27        1
# 44        1
# 45        1
# 50        1
# 60        1
# 75        1
# 80        1
# 84        1
# 88        1
# 99        1
# 121       1
# 143       1
# 144       1
# 165       1
# 204       1
# 420       1
# 1776      1
# Name: rating_numerator, dtype: int64

# %%
df_final.rating_numerator.describe()
# Out:
# count   2056.00...
# mean     12.265078
# std      40.867720
# min       0.000000
# 25%      10.000000
# 50%      11.000000
# 75%      12.000000
# max     1776.00...
# Name: rating_numerator, dtype: float64

# %% [raw]
# rating_numerator.describe()

# %%
#Checking Denominator rating
df_final.rating_denominator.value_counts().sort_index(ascending=True)
# Out:
# 2         1
# 7         1
# 10     2038
# 11        2
# 20        1
# 40        1
# 50        3
# 70        1
# 80        2
# 90        1
# 110       1
# 120       1
# 130       1
# 150       1
# 170       1
# Name: rating_denominator, dtype: int64

# %%
#Inspecting for duplicates
df_final.duplicated().sum()
# Out:
# 0

# %%
pd.set_option("max_colwidth", 30)
#Inspecting dog breeds
df_final[['p1', 'p2', 'p3']].describe(include=['object'])
# Out:
#                       p1                  p2                  p3
# count               2056                2056                2056
# unique               377                 402                 407
# top     golden_retriever  Labrador_retriever  Labrador_retriever
# freq                 150                 104                  79

# %%
#Inspecting confidence levels
df_final[['p1_conf', 'p2_conf',
          'p3_conf']].describe().loc[['min', 'max', 'mean']].round(5)
# Out:
#       p1_conf  p2_conf  p3_conf
# min  0.044330 0.000000 0.000000
# max  1.000000 0.488010 0.273420
# mean 0.594390 0.134770 0.060400

# %%
#Inspecting dog stages
df_final[['doggo', 'floofer', 'pupper', 'puppo']].apply(pd.Series.value_counts)
# Out:
#               doggo     floofer      pupper       puppo
# None    1978.000000 2048.000000 1836.000000 2032.000000
# doggo     78.000000         NaN         NaN         NaN
# floofer         NaN    8.000000         NaN         NaN
# pupper          NaN         NaN  220.000000         NaN
# puppo           NaN         NaN         NaN   24.000000

# %%
#Inspecting Names
df_final.name.loc[50:60]
# Out:
# 50      None
# 51         a
# 52     Carll
# 53    Klevin
# 54      None
# 55      Keet
# 56      None
# 57      Dave
# 58     Clybe
# 59      Gabe
# 60      None
# Name: name, dtype: object

# %%
#Inspecting favorite and retweet count
df_final[['favorite_count', 'p1', 'p2', 'p3']].min()
# Out:
# favorite_count               0
# p1                Afghan_hound
# p2                Afghan_hound
# p3                Afghan_hound
# dtype: object

# %%
df_final[['retweet_count', 'p1', 'p2', 'p3']].max()
# Out:
# retweet_count          69521
# p1                     zebra
# p2               wood_rabbit
# p3                     zebra
# dtype: object

# %% [markdown]
#  ## Observations:
#  Quality Issues:
#  - Completeness: 10124 missing records.
#  - Incorrect datatype in columns: `"tweet_id"`,`"timestamp"`
#  - The `"name"` column has accuracy issues
#  - The `"in_reply_to_status_id"`, `"in_reply_to_user_id`` columns has missing values and we are not interest in replies.
#  - The `"p1"`,`"p2"`,`"p3"` columns with validity and consistency issues
#  - The `"p1_dog"`,`"p2_dog"`,`"p3_dog"` columns  with validity issues
#  - We can observe that there are some 'None',objects present in `"doggo"`,`"floofer"`,`"pupper"` and`"puppo"` which have to be convert into 'NaN'
#
# - The `"retweeted_status_id"`, `"retweeted_status_user_id"`,`"retweeted_status_timestamp"` are related to retweets should be dropped
#
#
#
# ## Tidyness
# - The `"p1_conf"`,`"p2_conf"`,`"p3_conf"` are related to dog test, shoud be converted to one column
# - The `"doggo"`,`"floofer"`,`"pupper"` and`"puppo"` are related to dog stage and doesnt follow rules of tidy data.

# %%
#Creating copies before cleaning
# Making a copies of original pieces
twitter_api_clean = twitter_api.copy()
archive_clean = archive.copy()
predict_clean = predict.copy()

# %% [markdown]
# ## Clean

# %% [markdown]
# ### 1. Define
# Using pd.isna() on:
# `'in_reply_to_status_id','in_reply_to_user_id','retweeted_status_id',
#  'retweeted_status_user_id','retweeted_status_timestamp'`

# %% [markdown]
# ### Code

# %%
archive_clean = archive_clean[archive_clean['in_reply_to_status_id'].isna()]
archive_clean = archive_clean[archive_clean['in_reply_to_user_id'].isna()]
archive_clean = archive_clean[archive_clean['retweeted_status_id'].isna()]
archive_clean = archive_clean[archive_clean['retweeted_status_user_id'].isna()]
archive_clean = archive_clean[archive_clean['retweeted_status_timestamp'].isna()]

# %% [markdown]
# ### Test

# %%
archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2097 non-null   int64
#  1   in_reply_to_status_id       0 non-null      float64
#  2   in_reply_to_user_id         0 non-null      float64
#  3   timestamp                   2097 non-null   object
#  4   source                      2097 non-null   object
#  5   text                        2097 non-null   object
#  6   retweeted_status_id         0 non-null      float64
#  7   retweeted_status_user_id    0 non-null      float64
#  8   retweeted_status_timestamp  0 non-null      object
#  9   expanded_urls               2094 non-null   object
#  10  rating_numerator            2097 non-null   int64
#  11  rating_denominator          2097 non-null   int64
#  12  name                        2097 non-null   object
#  13  doggo                       2097 non-null   object
#  14  floofer                     2097 non-null   object
#  15  pupper                      2097 non-null   object
#  16  puppo                       2097 non-null   object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 294.9+ KB

# %% [markdown]
# ### 2. Define
#  Fixing Dog Stages

# %%
# replacing the stage name with 1, and 'None' with 0, like a dummy variable
make_dummy = lambda x: 0 if x == 'None' else 1

archive_clean.doggo = archive_clean.doggo.apply(make_dummy)
archive_clean.floofer = archive_clean.floofer.apply(make_dummy)
archive_clean.pupper = archive_clean.pupper.apply(make_dummy)
archive_clean.puppo = archive_clean.puppo.apply(make_dummy)

# by adding the stage columns, we can see how many are 'none' and how many stages are set
archive_clean['none'] = archive_clean['doggo'] + archive_clean['floofer'] + \
                        archive_clean['pupper'] + archive_clean['puppo']

# %%
stage_none = lambda x: 1 if x == 0 else 0

archive_clean['none'] = archive_clean['none'].apply(stage_none)

stage = ['floofer', 'puppo', 'doggo', 'pupper', 'none']

conditions = [(archive_clean[stage[0]] == 1), (archive_clean[stage[1]] == 1),
              (archive_clean[stage[2]] == 1), (archive_clean[stage[3]] == 1),
              (archive_clean[stage[4]] == 1)]

archive_clean['stage'] = np.select(conditions, stage, default=stage[4])

archive_clean.drop(stage, axis=1, inplace=True)

archive_clean['stage'] = archive_clean.stage.astype('category')

# Source for algorithm:    https://code.i-harness.com/en/q/19c9fbcm/en/q/19c9fbc

# %% [markdown]
# ### Test

# %%
archive_clean.stage.value_counts()
# Out:
# none       1761
# pupper      221
# doggo        81
# puppo        24
# floofer      10
# Name: stage, dtype: int64

# %% [markdown]
# ### 4. Define
#  Change ['timestamp'] using pd.to_datetime

# %% [markdown]
# ### Code

# %%
archive_clean['timestamp'] = pd.to_datetime(archive_clean['timestamp'])

# %% [markdown]
# ### Test

# %%
archive_clean.timestamp.dtypes
# Out:
# datetime64[ns, UTC]

# %% [markdown]
# ### 5. Define
# - Change tweet_id datatype in dataframe from int64 to object

# %% [markdown]
# ### Code

# %%
archive_clean['tweet_id'] = archive_clean['tweet_id'].astype(str)
predict_clean['tweet_id'] = archive_clean['tweet_id'].astype(str)
twitter_api_clean['tweet_id'] = archive_clean['tweet_id'].astype(str)

# %% [markdown]
# ### Test

# %%
archive_clean.tweet_id.dtype
# Out:
# dtype('O')

# %%
predict_clean.tweet_id.dtype
# Out:
# dtype('O')

# %%
twitter_api_clean.tweet_id.dtype
# Out:
# dtype('O')

# %% [markdown]
# ### 6. Define
# -  Creating new 'breed' and 'confidence' collumn

# %% [markdown]
# ### Code

# %%
breed = []
confidence = []


def choose_breed(predict_clean):
    if predict_clean['p1_dog'] == True:
        breed.append(predict_clean['p1'])
        confidence.append(predict_clean['p1_conf'])
    else:
        breed.append('Unknown')
        confidence.append(0)


# function call
predict_clean.apply(choose_breed, axis=1)
# add the two columns
predict_clean['breed'] = breed
predict_clean['confidence'] = confidence
predict_clean.sample(1)
# Out:
#                tweet_id                        jpg_url  img_num   p1  p1_conf  \
# 830  768855141948723200  https://pbs.twimg.com/medi...        1  pug 0.841987
#
#      p1_dog              p2  p2_conf  p2_dog           p3  p3_conf  p3_dog  \
# 830    True  French_bulldog 0.069791    True  Boston_bull 0.038720    True
#
#     breed  confidence
# 830   pug    0.841987

# %%
#fixing breed spelling
predict_clean['breed'] = predict_clean['breed'].str.replace('_', ' ')

# %%
# Converting all breeds to lower case
predict_clean['breed'] = predict_clean['breed'].str.lower()

# %%
predict_clean.breed.str.replace('Unknown', 'np.nan')
# Out:
# 0       welsh springer spaniel
# 1                      redbone
# 2              german shepherd
# 3          rhodesian ridgeback
# 4           miniature pinscher
#                  ...
# 2070                    basset
# 2071                   unknown
# 2072                 chihuahua
# 2073                 chihuahua
# 2074                   unknown
# Name: breed, Length: 2075, dtype: object

# %% [markdown]
# ### Test

# %%
predict_clean.breed.value_counts()
# Out:
# unknown               543
# golden retriever      150
# labrador retriever    100
# pembroke               89
# chihuahua              83
#                      ...
# japanese spaniel        1
# scotch terrier          1
# standard schnauzer      1
# entlebucher             1
# clumber                 1
# Name: breed, Length: 112, dtype: int64

# %% [markdown]
# ### 8. Define
# - Converting None to NaN

# %% [markdown]
# ### Code

# %%
archive_clean.replace(to_replace='None', value=np.nan, inplace=True)
archive_clean.replace(to_replace='Unknown', value=np.nan, inplace=True)
archive_clean.replace(to_replace='unknown', value=np.nan, inplace=True)

# %% [markdown]
# ### Test

# %%
archive_clean[archive_clean == 'None']
# Out:
#      tweet_id  in_reply_to_status_id  in_reply_to_user_id timestamp source  \
# 0         NaN                    NaN                  NaN       NaT    NaN
# 1         NaN                    NaN                  NaN       NaT    NaN
# 2         NaN                    NaN                  NaN       NaT    NaN
# 3         NaN                    NaN                  NaN       NaT    NaN
# 4         NaN                    NaN                  NaN       NaT    NaN
# ...       ...                    ...                  ...       ...    ...
# 2351      NaN                    NaN                  NaN       NaT    NaN
# 2352      NaN                    NaN                  NaN       NaT    NaN
# 2353      NaN                    NaN                  NaN       NaT    NaN
# 2354      NaN                    NaN                  NaN       NaT    NaN
# 2355      NaN                    NaN                  NaN       NaT    NaN
#
#      text  retweeted_status_id  retweeted_status_user_id  \
# 0     NaN                  NaN                       NaN
# 1     NaN                  NaN                       NaN
# 2     NaN                  NaN                       NaN
# 3     NaN                  NaN                       NaN
# 4     NaN                  NaN                       NaN
# ...   ...                  ...                       ...
# 2351  NaN                  NaN                       NaN
# 2352  NaN                  NaN                       NaN
# 2353  NaN                  NaN                       NaN
# 2354  NaN                  NaN                       NaN
# 2355  NaN                  NaN                       NaN
#
#       retweeted_status_timestamp expanded_urls  rating_numerator  \
# 0                            NaN           NaN               NaN
# 1                            NaN           NaN               NaN
# 2                            NaN           NaN               NaN
# 3                            NaN           NaN               NaN
# 4                            NaN           NaN               NaN
# ...                          ...           ...               ...
# 2351                         NaN           NaN               NaN
# 2352                         NaN           NaN               NaN
# 2353                         NaN           NaN               NaN
# 2354                         NaN           NaN               NaN
# 2355                         NaN           NaN               NaN
#
#       rating_denominator name stage
# 0                    NaN  NaN   NaN
# 1                    NaN  NaN   NaN
# 2                    NaN  NaN   NaN
# 3                    NaN  NaN   NaN
# 4                    NaN  NaN   NaN
# ...                  ...  ...   ...
# 2351                 NaN  NaN   NaN
# 2352                 NaN  NaN   NaN
# 2353                 NaN  NaN   NaN
# 2354                 NaN  NaN   NaN
# 2355                 NaN  NaN   NaN
#
# [2097 rows x 14 columns]

# %% [markdown]
# # Final View

# %%
df_clean = twitter_api_clean.merge(archive_clean,on='tweet_id',how="right").merge(predict_clean,on='tweet_id',how="right")

# %%
df_clean.sample(3)
# Out:
#                tweet_id  retweet_count  favorite_count  in_reply_to_status_id  \
# 390  826240494070030336     266.000000      912.000000                    NaN
# 271  841077006473256960     158.000000      659.000000                    NaN
# 506                 NaN            NaN             NaN                    NaN
#
#      in_reply_to_user_id                 timestamp  \
# 390                  NaN 2017-01-31 01:27:39+00:00
# 271                  NaN 2017-03-13 00:02:39+00:00
# 506                  NaN                       NaT
#
#                             source                           text  \
# 390  <a href="http://twitter.co...  We only rate dogs. Please ...
# 271  <a href="http://twitter.co...  This is Dawn. She's just c...
# 506                            NaN                            NaN
#
#      retweeted_status_id  retweeted_status_user_id  \
# 390                  NaN                       NaN
# 271                  NaN                       NaN
# 506                  NaN                       NaN
#
#      retweeted_status_timestamp                  expanded_urls  \
# 390                         NaN  https://twitter.com/dog_ra...
# 271                         NaN  https://twitter.com/dog_ra...
# 506                         NaN                            NaN
#
#      rating_numerator  rating_denominator  name stage  \
# 390         11.000000           10.000000   NaN  none
# 271         12.000000           10.000000  Dawn  none
# 506               NaN                 NaN   NaN   NaN
#
#                            jpg_url  img_num                  p1  p1_conf  \
# 390  https://pbs.twimg.com/medi...        1                  ox 0.193431
# 271  https://pbs.twimg.com/medi...        1  Labrador_retriever 0.947453
# 506  https://pbs.twimg.com/medi...        1  Labrador_retriever 0.407430
#
#      p1_dog                           p2  p2_conf  p2_dog          p3  \
# 390   False                      warthog 0.123827   False       bison
# 271    True  German_short-haired_pointer 0.017001    True  Weimaraner
# 506    True                     malinois 0.077037    True         pug
#
#      p3_conf  p3_dog               breed  confidence
# 390 0.111177   False             unknown    0.000000
# 271 0.015432    True  labrador retriever    0.947453
# 506 0.074597    True  labrador retriever    0.407430

# %%
#saving to csv
df_clean.to_csv('twitter_archive_master.csv',index=False)

# %% [markdown]
# # Visuals

# %%
def labels_and_title(x, y, title):
    plt.xlabel(x)
    plt.ylabel(y)
    plt.title(title)
    return labels_and_title


#Pick a palette
sns.color_palette("rocket", as_cmap=True)
# Generating a graphical plot for the data
sns.set(rc={'figure.figsize': (10, 8)})

# %% [markdown]
# # Question 1: What is WeRateDogs's posting trend overtime?

# %%
years = df_clean.timestamp.dt.year
ret_fav = df_clean.pivot_table(index=years, values=['favorite_count','retweet_count'], aggfunc='sum')
ret_fav
ret_fav.groupby(years).plot(kind='line')
plt.title('Retweeting and Favoriting trend over time')
plt.ylabel('Count')
plt.xlabel('(Year)')
plt.legend(('Retweets', 'Favorites'))
plt.savefig('ret_fav')

# %% [markdown]
# ###  Regarding to activity overtime, we can cleary notice a drop from 2016 to 2017 with a diference of 42,09 % in `"favorite_count"`, and  a drop from 2016 to 2017 with a diference of 49,96 % in `"retweet_count"`.

# %% [markdown]
# ## Question 2: Which breed of dogs got the highest  favorite counts?

# %%
color = (sns.color_palette("husl", 10))
sns.set(rc={'figure.figsize': (15, 4)})
sns.set(font_scale=1)
pivot_breed= df_clean.pivot_table(index=['breed'], values=['favorite_count'], aggfunc='sum').sort_values(by="favorite_count",ascending=False)

ax = sns.barplot(x='favorite_count', y=pivot_breed.index, data=pivot_breed, palette=color,order=df_clean.breed.value_counts().iloc[:10].index, )
plt.title('Highest favorite count per breed')
plt.ylabel('Favorite Count')
plt.xlabel('Breed')
plt.savefig('breed')
for i in ax.containers:
    ax.bar_label(i,)
    pd.set_option('float_format', '{:f}'.format)

# %%
pivot_stage
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [53], in <cell line: 1>()
# ----> 1 pivot_stage
#
# NameError: name 'pivot_stage' is not defined

# %% [markdown]
# ###   We can observe that "golden retriever" breed  with 1,257,407 likes, in second place we have the Labrador Retriever with 811848 likes and in the third place the "pembroke" with 601228.

# %% [markdown]
# ## Question 3: Which stage of dogs got the highest favorite counts?¶

# %%
pivot_stage = df_clean.pivot_table(index=['stage'], values=['favorite_count'], aggfunc='sum')
pivot_stage
color = (sns.color_palette("husl", 4))
sns.set(rc={'figure.figsize': (10, 5)})
sns.set(font_scale=1)
#f = df_clean.sort_values(by='favorite_count', ascending=False)
ax = sns.barplot(y=pivot_stage.index,
                 x='favorite_count',
                 data=pivot_stage,
                 palette=color,
                 order=["pupper","doggo", "floofer",  "puppo"],
                 ci=None)
plt.title('Highest favorite count per stage')
plt.ylabel('')
plt.xlabel('')
plt.savefig('stages')
for i in ax.containers:
    ax.bar_label(i,)

# %% [markdown]
# ### Cleary the most common stage is `"pupper"` with a total of 2,052,302 of favorites, representing 84,19 % of all stages, excluding "nones".

# %%
#Showing Top Breed image
top_breed = df_clean[df_clean["breed"]=="golden retriever"]
url = top_breed.jpg_url.iloc[50]
response = requests.get(url)
Image.open(BytesIO(response.content))

# %%
import string

def substrings_in_string(big_string, substrings):
    matches = []
    for substring in substrings:
        if string.find(big_string, substring) != -1:
            matches.append(substring)
    if len(matches) == 0:
        print(big_string)
        return None
    else:
        return matches
